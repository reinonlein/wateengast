# %%
import rebrick
import pandas as pd

# %%
apikey = "62b6d0f51a49c3013da9e54002ccf53c"
usertoken = "938b2d06936cf9702d50a715cfa9260370e0975376778e94e6464216248dca24"
username = "Reinlalala"

# %%
rb = rebrick.Rebrick(apikey, usertoken, silent=True)

# %%
pd.DataFrame(rb.get_users_sets())
# Out:
#                                               0
# 0    SET ID: 10696-1, Medium Creative Brick Box
# 1      SET ID: 10720-1, Police Helicopter Chase
# 2          SET ID: 31005-1, Construction Hauler
# 3                 SET ID: 31042-1, Super Soarer
# 4        SET ID: 41135-1, Livi's Pop Star House
# ..                                          ...
# 109   SET ID: 21322-1, Pirates of Barracuda Bay
# 110     SET ID: 70670-1, Monastery of Spinjitzu
# 111                SET ID: 70677-1, Land Bounty
# 112  SET ID: 41391-1, Heartlake City Hair Salon
# 113            SET ID: 76146-1, Spider-Man Mech
#
# [114 rows x 1 columns]

# %%
pd.DataFrame(rb.get_users_elements(color_id=0))
# Out:
#                                                      0
# 0    Element ID: None, Part ID: 87087, Brick Specia...
# 1    Element ID: None, Part ID: 3039, Slope 45° 2 x...
# 2    Element ID: None, Part ID: 87580, Plate Specia...
# 3    Element ID: None, Part ID: 2654, Plate Round 2...
# 4    Element ID: None, Part ID: 3659, Brick Arch 1 ...
# ..                                                 ...
# 720  Element ID: None, Part ID: 973pr4910c01, Torso...
# 721  Element ID: None, Part ID: 15310pr0002, Minifi...
# 722  Element ID: None, Part ID: 34609pr0004, Torso ...
# 723  Element ID: None, Part ID: 2528pr0012, Minifig...
# 724  Element ID: None, Part ID: 973pr9740c01, Minif...
#
# [725 rows x 1 columns]

# %%
rb.get_users_elements()
# Out:
# [Element(Element ID: None, Part ID: 3023, Plate 1 x 2, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 3069b, Tile 1 x 2 with Groove, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 54200, Slope 30° 1 x 1 x 2/3 (Cheese Slope), Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 30602, Slope Curved 2 x 2 with Lip, No Studs, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 3024, Plate 1 x 1, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 3065, Brick 1 x 2 without Bottom Tube, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 87552, Panel 1 x 2 x 2 [Side Supports / Hollow Studs], Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 4176, Windscreen 2 x 6 x 2, Color ID: 40, Trans-Black, 635F52),
#  Element(Element ID: None, Part ID: 2447, Headwear Accessory Visor For Standard Helmet, Color ID: 40, Trans-Black, 635F52),
# ...

# %%
data = rb.get_users_partlists()

# %%
data = rb.get_users_sets()
print(data)

# %%
import json
import rebrick

# %%
rebrick.init(apikey, usertoken)

# %%
print("Get badge:")
rebrick.users.get_badge(1)
# Out:
# Get badge:

# %%
import pandas as pd

# %%
response = rebrick.users.get_badges()
data = json.loads(response.read())

# %%
data
# Out:
# {'count': 63,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 1,
#    'code': 'MOC',
#    'level': 1,
#    'name': 'MOC Designer',
#    'descr': 'Submit your first approved MOC.'},
#   {'id': 2,
#    'code': 'MOC',
#    'level': 2,
#    'name': 'MOC Designer',
#    'descr': 'Submit 10 approved MOCs.'},
#   {'id': 3,
#    'code': 'MOC',
#    'level': 3,
#    'name': 'MOC Designer',
#    'descr': 'Have over 100 approved MOCs.'},
#   {'id': 4,
#    'code': 'TECH',
#    'level': 1,
#    'name': 'Technic Builder',
#    'descr': 'Submit an approved MOC within the Technic theme (or sub-themes).'},
#   {'id': 5,
#    'code': 'TECH',
#    'level': 2,
#    'name': 'Technic Expert',
#    'descr': 'Submit 10 approved MOCs within the Technic theme (or sub-themes).'},
#   {'id': 6,
#    'code': 'TECH',
#    'level': 3,
#    'name': 'Technic Master',
#    'descr': 'Submit 50 approved MOCs within the Technic theme (or sub-themes).'},
#   {'id': 7,
#    'code': 'MB',
#    'level': 1,
# ...

# %%
response = rebrick.users.get_elements(color_id=0)
data = json.loads(response.read())

# %%
len(data['results'])
# Out:
# 100

# %%
from pandas.io.json import json_normalize

# %%
json = {
  "count": 65,
  "next": null,
  "previous": null,
  "results": [
    {
      "id": 1,
      "name": "Baseplates",
      "part_count": 231
    },
    {
      "id": 3,
      "name": "Bricks Sloped",
      "part_count": 487
    },
    {
      "id": 4,
      "name": "Duplo, Quatro and Primo",
      "part_count": 3284
    },
    {
      "id": 5,
      "name": "Bricks Special",
      "part_count": 124
    },
    {
      "id": 6,
      "name": "Bricks Wedged",
      "part_count": 219
    },
    {
      "id": 7,
      "name": "Containers",
      "part_count": 163
    },
    {
      "id": 8,
      "name": "Technic Bricks",
      "part_count": 26
    },
    {
      "id": 9,
      "name": "Plates Special",
      "part_count": 204
    },
    {
      "id": 11,
      "name": "Bricks",
      "part_count": 1007
    },
    {
      "id": 12,
      "name": "Technic Connectors",
      "part_count": 96
    },
    {
      "id": 13,
      "name": "Minifigs",
      "part_count": 533
    },
    {
      "id": 14,
      "name": "Plates",
      "part_count": 78
    },
    {
      "id": 15,
      "name": "Tiles Special",
      "part_count": 304
    },
    {
      "id": 16,
      "name": "Windows and Doors",
      "part_count": 425
    },
    {
      "id": 17,
      "name": "Non-LEGO",
      "part_count": 1294
    },
    {
      "id": 18,
      "name": "Hinges, Arms and Turntables",
      "part_count": 209
    },
    {
      "id": 19,
      "name": "Tiles",
      "part_count": 1381
    },
    {
      "id": 20,
      "name": "Bricks Round and Cones",
      "part_count": 318
    },
    {
      "id": 21,
      "name": "Plates Round and Dishes",
      "part_count": 212
    },
    {
      "id": 22,
      "name": "Pneumatics",
      "part_count": 35
    },
    {
      "id": 23,
      "name": "Panels",
      "part_count": 272
    },
    {
      "id": 24,
      "name": "Other",
      "part_count": 196
    },
    {
      "id": 25,
      "name": "Technic Steering, Suspension and Engine",
      "part_count": 85
    },
    {
      "id": 26,
      "name": "Technic Special",
      "part_count": 189
    },
    {
      "id": 27,
      "name": "Minifig Accessories",
      "part_count": 1386
    },
    {
      "id": 28,
      "name": "Plants and Animals",
      "part_count": 1033
    },
    {
      "id": 29,
      "name": "Wheels and Tyres",
      "part_count": 291
    },
    {
      "id": 30,
      "name": "Tubes and Hoses",
      "part_count": 166
    },
    {
      "id": 31,
      "name": "String, Bands and Reels",
      "part_count": 93
    },
    {
      "id": 32,
      "name": "Bars, Ladders and Fences",
      "part_count": 118
    },
    {
      "id": 33,
      "name": "Rock",
      "part_count": 44
    },
    {
      "id": 34,
      "name": "Supports, Girders and Cranes",
      "part_count": 81
    },
    {
      "id": 35,
      "name": "Transportation - Sea and Air",
      "part_count": 227
    },
    {
      "id": 36,
      "name": "Transportation - Land",
      "part_count": 511
    },
    {
      "id": 37,
      "name": "Bricks Curved",
      "part_count": 397
    },
    {
      "id": 38,
      "name": "Flags, Signs, Plastics and Cloth",
      "part_count": 782
    },
    {
      "id": 39,
      "name": "Magnets and Holders",
      "part_count": 41
    },
    {
      "id": 40,
      "name": "Technic Panels",
      "part_count": 63
    },
    {
      "id": 41,
      "name": "Bionicle, Hero Factory and Constraction",
      "part_count": 1224
    },
    {
      "id": 42,
      "name": "Belville, Scala and Fabuland",
      "part_count": 594
    },
    {
      "id": 43,
      "name": "Znap",
      "part_count": 22
    },
    {
      "id": 44,
      "name": "Mechanical",
      "part_count": 29
    },
    {
      "id": 45,
      "name": "Power Functions, Mindstorms and Electric",
      "part_count": 495
    },
    {
      "id": 46,
      "name": "Technic Axles",
      "part_count": 28
    },
    {
      "id": 47,
      "name": "Windscreens and Fuselage",
      "part_count": 339
    },
    {
      "id": 48,
      "name": "Clikits",
      "part_count": 287
    },
    {
      "id": 49,
      "name": "Plates Angled",
      "part_count": 71
    },
    {
      "id": 50,
      "name": "HO Scale",
      "part_count": 27
    },
    {
      "id": 51,
      "name": "Technic Beams",
      "part_count": 33
    },
    {
      "id": 52,
      "name": "Technic Gears",
      "part_count": 79
    },
    {
      "id": 53,
      "name": "Technic Pins",
      "part_count": 21
    },
    {
      "id": 54,
      "name": "Technic Bushes",
      "part_count": 8
    },
    {
      "id": 55,
      "name": "Technic Beams Special",
      "part_count": 26
    },
    {
      "id": 56,
      "name": "Tools",
      "part_count": 12
    },
    {
      "id": 57,
      "name": "Non-Buildable Figures (Duplo, Fabuland, etc)",
      "part_count": 732
    },
    {
      "id": 58,
      "name": "Stickers",
      "part_count": 2027
    },
    {
      "id": 59,
      "name": "Minifig Heads",
      "part_count": 3301
    },
    {
      "id": 60,
      "name": "Minifig Upper Body",
      "part_count": 5005
    },
    {
      "id": 61,
      "name": "Minifig Lower Body",
      "part_count": 1761
    },
    {
      "id": 62,
      "name": "Minidoll Heads",
      "part_count": 134
    },
    {
      "id": 63,
      "name": "Minidoll Upper Body",
      "part_count": 307
    },
    {
      "id": 64,
      "name": "Minidoll Lower Body",
      "part_count": 222
    },
    {
      "id": 65,
      "name": "Minifig Headwear",
      "part_count": 1466
    },
    {
      "id": 66,
      "name": "Modulex",
      "part_count": 219
    },
    {
      "id": 67,
      "name": "Tiles Round and Curved",
      "part_count": 370
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fdd4a07cb390> in <module>
#       1 json = {
#       2   "count": 65,
# ----> 3   "next": null,
#       4   "previous": null,
#       5   "results": [
#
# NameError: name 'null' is not defined

# %%
df = json_normalize(data['results'])

# %%
df
# Out:
#     quantity part.part_num                                          part.name  \
# 0         29         87087            Brick Special 1 x 1 with Stud on 1 Side
# 1          6          3039                                    Slope 45° 2 x 2
# 2          3         87580  Plate Special 2 x 2 with Groove and Center Stu...
# 3         26          2654  Plate Round 2 x 2 with Rounded Bottom [Boat Stud]
# 4          3          3659                                   Brick Arch 1 x 4
# ..       ...           ...                                                ...
# 95        53         32140                   Technic Beam 2 x 4 L-Shape Thick
# 96        17         63868    Plate Special 1 x 2 with Clip Horizontal on End
# 97        14         11153  Slope Curved 4 x 1 No Studs [Stud Holder with ...
# 98         2          3938                   Hinge Brick 1 x 2 Top Plate Thin
# 99         3         64683  Technic Panel Fairing # 3 Small Smooth Long, S...
#
# ...

# %%
len(rb.get_colors())

# %%
rb.get_parts()

# %%
rb.get_themes()

# %%
jsonstring = "{
  "count": 4971,
  "next": "https://rebrickable.com/api/v3/users/938b2d06936cf9702d50a715cfa9260370e0975376778e94e6464216248dca24/allparts/?page=2",
  "previous": null,
  "results": [
    {
      "quantity": 2,
      "part": {
        "part_num": "3023",
        "name": "Plate 1 x 2",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3023/plate-1-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302326.jpg",
        "external_ids": {
          "BrickOwl": [
            "44980"
          ],
          "Brickset": [
            "28653",
            "3023",
            "6225"
          ],
          "LDraw": [
            "28653",
            "3023"
          ],
          "LEGO": [
            "28653",
            "3023",
            "6225"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "3069b",
        "name": "Tile 1 x 2 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/3069b/tile-1-x-2-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/306901.jpg",
        "external_ids": {
          "BrickLink": [
            "3069b"
          ],
          "BrickOwl": [
            "487300"
          ],
          "Brickset": [
            "15598",
            "30070",
            "3069",
            "35386",
            "45880",
            "59489",
            "63286"
          ],
          "LEGO": [
            "15598",
            "30070",
            "3069",
            "35386",
            "45880",
            "59489",
            "63286"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 18,
      "part": {
        "part_num": "54200",
        "name": "Slope 30° 1 x 1 x 2/3 (Cheese Slope)",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/54200/slope-30-1-x-1-x-23-cheese-slope/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4504382.jpg",
        "external_ids": {
          "BrickOwl": [
            "158788"
          ],
          "LEGO": [
            "18862",
            "33847",
            "35338",
            "50746",
            "54200",
            "63290"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "30602",
        "name": "Slope Curved 2 x 2 with Lip, No Studs",
        "part_cat_id": 37,
        "part_url": "https://rebrickable.com/parts/30602/slope-curved-2-x-2-with-lip-no-studs/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4217722.jpg",
        "external_ids": {
          "BrickOwl": [
            "457645"
          ],
          "LEGO": [
            "28659",
            "47904",
            "54415"
          ],
          "Peeron": [
            "47904"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 6,
      "part": {
        "part_num": "3024",
        "name": "Plate 1 x 1",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3024/plate-1-x-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302401.jpg",
        "external_ids": {
          "BrickOwl": [
            "322944"
          ],
          "LEGO": [
            "30008",
            "63326"
          ],
          "Peeron": [
            "30008"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 9,
      "part": {
        "part_num": "3065",
        "name": "Brick 1 x 2 without Bottom Tube",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3065/brick-1-x-2-without-bottom-tube/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/306540.jpg",
        "external_ids": {
          "BrickOwl": [
            "887549"
          ],
          "LEGO": [
            "35743"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 8,
      "part": {
        "part_num": "87552",
        "name": "Panel 1 x 2 x 2 [Side Supports / Hollow Studs]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/87552/panel-1-x-2-x-2-side-supports-hollow-studs/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4640026.jpg",
        "external_ids": {
          "BrickOwl": [
            "915460"
          ],
          "Brickset": [
            "35378"
          ],
          "LEGO": [
            "35378",
            "87552",
            "94638"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 6,
      "part": {
        "part_num": "4176",
        "name": "Windscreen 2 x 6 x 2",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/4176/windscreen-2-x-6-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4142682.jpg",
        "external_ids": {
          "BrickOwl": [
            "966967"
          ],
          "Brickset": [
            "35336",
            "4176"
          ],
          "LEGO": [
            "30607",
            "35336",
            "4176"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 61,
      "part": {
        "part_num": "2447",
        "name": "Headwear Accessory Visor For Standard Helmet",
        "part_cat_id": 27,
        "part_url": "https://rebrickable.com/parts/2447/headwear-accessory-visor-for-standard-helmet/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4163306.jpg",
        "external_ids": {
          "BrickOwl": [
            "285450"
          ],
          "LEGO": [
            "59456",
            "70651",
            "88407"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 8,
      "part": {
        "part_num": "4865b",
        "name": "Panel 1 x 2 x 1 [Rounded Corners]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/4865b/panel-1-x-2-x-1-rounded-corners/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6146223.jpg",
        "external_ids": {
          "BrickOwl": [
            "483249"
          ],
          "LEGO": [
            "15714",
            "26169",
            "4865"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 5,
      "part": {
        "part_num": "92583",
        "name": "Windscreen 3 x 6 x 2",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/92583/windscreen-3-x-6-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4599456.jpg",
        "external_ids": {
          "BrickOwl": [
            "812038"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "60601",
        "name": "Glass for Window 1 x 2 x 2 Flat",
        "part_cat_id": 16,
        "part_url": "https://rebrickable.com/parts/60601/glass-for-window-1-x-2-x-2-flat/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4542078.jpg",
        "external_ids": {
          "BrickOwl": [
            "716419"
          ],
          "LEGO": [
            "35316",
            "86209"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "6267",
        "name": "Windscreen 2 x 12 x 4",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/6267/windscreen-2-x-12-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4566531.jpg",
        "external_ids": {
          "BrickOwl": [
            "905831"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "18908",
        "name": "Glass for Aircraft Fuselage Curved Forward 6 x 10 Top with 5 Window Panes",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/18908/glass-for-aircraft-fuselage-curved-forward-6-x-10-top-with-5-window-panes/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6114089.jpg",
        "external_ids": {
          "BrickOwl": [
            "18894"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "18973",
        "name": "Windscreen 6 x 4 x 1 Curved",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/18973/windscreen-6-x-4-x-1-curved/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6102582.jpg",
        "external_ids": {
          "BrickOwl": [
            "827999"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "92579",
        "name": "Windscreen 8 x 4 x 2 with 4 Studs and Handle",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/92579/windscreen-8-x-4-x-2-with-4-studs-and-handle/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4598530.jpg",
        "external_ids": {
          "BrickOwl": [
            "216731"
          ],
          "Brickset": [
            "38480",
            "92579"
          ],
          "LEGO": [
            "38480",
            "92579"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "6238",
        "name": "Windscreen 4 x 4 x 1",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/6238/windscreen-4-x-4-x-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4206667.jpg",
        "external_ids": {
          "BrickOwl": [
            "498321"
          ],
          "Peeron": [
            "6238a"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "60616a",
        "name": "Door 1 x 4 x 6 Smooth with Square Handle Plinth",
        "part_cat_id": 16,
        "part_url": "https://rebrickable.com/parts/60616a/door-1-x-4-x-6-smooth-with-square-handle-plinth/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4521504.jpg",
        "external_ids": {
          "BrickLink": [
            "60616"
          ],
          "BrickOwl": [
            "755387"
          ],
          "LEGO": [
            "60616"
          ],
          "Peeron": [
            "60616"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "95228",
        "name": "Equipment Bottle",
        "part_cat_id": 27,
        "part_url": "https://rebrickable.com/parts/95228/equipment-bottle/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4620380.jpg",
        "external_ids": {
          "BrickOwl": [
            "250898"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "87544",
        "name": "Panel 1 x 2 x 3 [Side Supports / Hollow Studs]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/87544/panel-1-x-2-x-3-side-supports-hollow-studs/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4585429.jpg",
        "external_ids": {
          "BrickOwl": [
            "730588"
          ],
          "LEGO": [
            "74968"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "92279",
        "name": "Windscreen 7 x 4 x 2 Round with Handle",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/92279/windscreen-7-x-4-x-2-round-with-handle/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4650628.jpg",
        "external_ids": {
          "BrickOwl": [
            "384460"
          ],
          "Brickset": [
            "35373",
            "92279"
          ],
          "LEGO": [
            "35373",
            "92279"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "84954",
        "name": "Windscreen 3 x 4 x 3",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/84954/windscreen-3-x-4-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4543458.jpg",
        "external_ids": {
          "BrickOwl": [
            "245195"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "3823",
        "name": "Windscreen 2 x 4 x 2",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/3823/windscreen-2-x-4-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/382340.jpg",
        "external_ids": {
          "BrickOwl": [
            "901078"
          ],
          "Brickset": [
            "35260",
            "3823"
          ],
          "LEGO": [
            "35260",
            "3823"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 5,
      "part": {
        "part_num": "57783",
        "name": "Windscreen 3 x 4 x 1 1/3 Large Glass Surface",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/57783/windscreen-3-x-4-x-1-13-large-glass-surface/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4498374.jpg",
        "external_ids": {
          "BrickOwl": [
            "292654"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "64453",
        "name": "Windscreen 1 x 6 x 3",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/64453/windscreen-1-x-6-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4546691.jpg",
        "external_ids": {
          "BrickOwl": [
            "605273"
          ],
          "Brickset": [
            "39889",
            "64453"
          ],
          "LEGO": [
            "39889",
            "64453"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "60581",
        "name": "Panel 1 x 4 x 3 [Side Supports / Hollow Studs]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/60581/panel-1-x-4-x-3-side-supports-hollow-studs/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4594686.jpg",
        "external_ids": {
          "BrickOwl": [
            "536534"
          ],
          "LEGO": [
            "87543"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "2437",
        "name": "Windscreen 3 x 4 x 1 1/3 with 2 Studs on Top",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/2437/windscreen-3-x-4-x-1-13-with-2-studs-on-top/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4124083.jpg",
        "external_ids": {
          "BrickOwl": [
            "126972"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "59900",
        "name": "Cone 1 x 1 [Top Groove]",
        "part_cat_id": 20,
        "part_url": "https://rebrickable.com/parts/59900/cone-1-x-1-top-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4529236.jpg",
        "external_ids": {
          "BrickLink": [
            "4589b"
          ],
          "BrickOwl": [
            "583545"
          ],
          "Brickset": [
            "28701",
            "59900"
          ],
          "LEGO": [
            "15551",
            "28701",
            "59900",
            "64288"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "72475",
        "name": "Windscreen 3 x 4 x 4 Inverted, Rounded Top Inside Edges, Cut-Out Bottom Inside Edges",
        "part_cat_id": 47,
        "part_url": "https://rebrickable.com/parts/72475/windscreen-3-x-4-x-4-inverted-rounded-top-inside-edges-cut-out-bottom-inside-edges/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6247801.jpg",
        "external_ids": {
          "BrickOwl": [
            "197637"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 40,
        "name": "Trans-Black",
        "rgb": "635F52",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              13
            ],
            "ext_descrs": [
              [
                "Trans-Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              95
            ],
            "ext_descrs": [
              [
                "Transparent Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              111
            ],
            "ext_descrs": [
              [
                "Tr. Brown",
                "TR.BROWN"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "smoke"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              40
            ],
            "ext_descrs": [
              [
                "Trans_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 10,
      "part": {
        "part_num": "6091",
        "name": "Brick Curved 1 x 2 x 1 1/3 with Curved Top",
        "part_cat_id": 37,
        "part_url": "https://rebrickable.com/parts/6091/brick-curved-1-x-2-x-1-13-with-curved-top/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/609101.jpg",
        "external_ids": {
          "BrickOwl": [
            "60351"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 146,
      "part": {
        "part_num": "3023",
        "name": "Plate 1 x 2",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3023/plate-1-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302326.jpg",
        "external_ids": {
          "BrickOwl": [
            "44980"
          ],
          "Brickset": [
            "28653",
            "3023",
            "6225"
          ],
          "LDraw": [
            "28653",
            "3023"
          ],
          "LEGO": [
            "28653",
            "3023",
            "6225"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 8,
      "part": {
        "part_num": "41678",
        "name": "Technic Axle and Pin Connector Perpendicular Double Split",
        "part_cat_id": 12,
        "part_url": "https://rebrickable.com/parts/41678/technic-axle-and-pin-connector-perpendicular-double-split/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4162857.jpg",
        "external_ids": {
          "BrickOwl": [
            "652130"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 18,
      "part": {
        "part_num": "3040b",
        "name": "Slope 45° 2 x 1 with Bottom Pin",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/3040b/slope-45-2-x-1-with-bottom-pin/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/304026.jpg",
        "external_ids": {
          "BrickLink": [
            "3040"
          ],
          "BrickOwl": [
            "735007"
          ],
          "LDraw": [
            "3040b"
          ],
          "LEGO": [
            "3040",
            "35281",
            "6270"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 71,
      "part": {
        "part_num": "3005",
        "name": "Brick 1 x 1",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3005/brick-1-x-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300501.jpg",
        "external_ids": {
          "BrickOwl": [
            "656416"
          ],
          "Brickset": [
            "3005",
            "35382"
          ],
          "LDraw": [
            "30071"
          ],
          "LEGO": [
            "3005",
            "30071",
            "35382"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 15,
      "part": {
        "part_num": "44728",
        "name": "Bracket 1 x 2 - 2 x 2",
        "part_cat_id": 9,
        "part_url": "https://rebrickable.com/parts/44728/bracket-1-x-2-2-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4277928.jpg",
        "external_ids": {
          "BrickOwl": [
            "222977"
          ],
          "LEGO": [
            "21712",
            "86644",
            "92411"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 51,
      "part": {
        "part_num": "2412b",
        "name": "Tile Special 1 x 2 Grille with Bottom Groove",
        "part_cat_id": 15,
        "part_url": "https://rebrickable.com/parts/2412b/tile-special-1-x-2-grille-with-bottom-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4210631.jpg",
        "external_ids": {
          "BrickLink": [
            "2412b"
          ],
          "BrickOwl": [
            "363948"
          ],
          "LDraw": [
            "2412b",
            "30244"
          ],
          "LEGO": [
            "15561",
            "2412",
            "30244",
            "51815"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 32,
      "part": {
        "part_num": "32526",
        "name": "Technic Beam 3 x 5 L-Shape Thick",
        "part_cat_id": 51,
        "part_url": "https://rebrickable.com/parts/32526/technic-beam-3-x-5-l-shape-thick/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4142823.jpg",
        "external_ids": {
          "BrickOwl": [
            "733751"
          ],
          "LEGO": [
            "43886"
          ],
          "Peeron": [
            "153"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "28321",
        "name": "Minidoll Hair Long, Parted in Front and Swept Back Over Shoulders",
        "part_cat_id": 65,
        "part_url": "https://rebrickable.com/parts/28321/minidoll-hair-long-parted-in-front-and-swept-back-over-shoulders/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6171772.jpg",
        "external_ids": {
          "BrickOwl": [
            "618160"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 56,
      "part": {
        "part_num": "32013",
        "name": "Technic Axle and Pin Connector Angled #1",
        "part_cat_id": 12,
        "part_url": "https://rebrickable.com/parts/32013/technic-axle-and-pin-connector-angled-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4107085.jpg",
        "external_ids": {
          "BrickOwl": [
            "988519"
          ],
          "LEGO": [
            "42127"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "3659",
        "name": "Brick Arch 1 x 4",
        "part_cat_id": 37,
        "part_url": "https://rebrickable.com/parts/3659/brick-arch-1-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211435.jpg",
        "external_ids": {
          "BrickOwl": [
            "813461"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 26,
      "part": {
        "part_num": "2654",
        "name": "Plate Round 2 x 2 with Rounded Bottom [Boat Stud]",
        "part_cat_id": 21,
        "part_url": "https://rebrickable.com/parts/2654/plate-round-2-x-2-with-rounded-bottom-boat-stud/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/265426.jpg",
        "external_ids": {
          "BrickOwl": [
            "243161"
          ],
          "LEGO": [
            "28558",
            "54196",
            "93791"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "87580",
        "name": "Plate Special 2 x 2 with Groove and Center Stud (Jumper)",
        "part_cat_id": 9,
        "part_url": "https://rebrickable.com/parts/87580/plate-special-2-x-2-with-groove-and-center-stud-jumper/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4565393.jpg",
        "external_ids": {
          "BrickOwl": [
            "374469"
          ],
          "LEGO": [
            "23893"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 6,
      "part": {
        "part_num": "3039",
        "name": "Slope 45° 2 x 2",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/3039/slope-45-2-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/303921.jpg",
        "external_ids": {
          "BrickOwl": [
            "822931"
          ],
          "Brickset": [
            "3039",
            "35277",
            "63341"
          ],
          "LEGO": [
            "3039",
            "35277",
            "6227",
            "63341"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 29,
      "part": {
        "part_num": "87087",
        "name": "Brick Special 1 x 1 with Stud on 1 Side",
        "part_cat_id": 5,
        "part_url": "https://rebrickable.com/parts/87087/brick-special-1-x-1-with-stud-on-1-side/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4558953.jpg",
        "external_ids": {
          "BrickOwl": [
            "215571"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 26,
      "part": {
        "part_num": "15573",
        "name": "Plate Special 1 x 2 with 1 Stud with Groove and Inside Stud Holder (Jumper)",
        "part_cat_id": 9,
        "part_url": "https://rebrickable.com/parts/15573/plate-special-1-x-2-with-1-stud-with-groove-and-inside-stud-holder-jumper/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6066097.jpg",
        "external_ids": {
          "BrickOwl": [
            "893367"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 27,
      "part": {
        "part_num": "3069b",
        "name": "Tile 1 x 2 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/3069b/tile-1-x-2-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/306901.jpg",
        "external_ids": {
          "BrickLink": [
            "3069b"
          ],
          "BrickOwl": [
            "487300"
          ],
          "Brickset": [
            "15598",
            "30070",
            "3069",
            "35386",
            "45880",
            "59489",
            "63286"
          ],
          "LEGO": [
            "15598",
            "30070",
            "3069",
            "35386",
            "45880",
            "59489",
            "63286"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 20,
      "part": {
        "part_num": "3622",
        "name": "Brick 1 x 3",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3622/brick-1-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/362201.jpg",
        "external_ids": {
          "BrickOwl": [
            "367537"
          ],
          "LDraw": [
            "45505"
          ],
          "LEGO": [
            "45505"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 53,
      "part": {
        "part_num": "3941",
        "name": "Brick Round 2 x 2 with Axle Hole",
        "part_cat_id": 20,
        "part_url": "https://rebrickable.com/parts/3941/brick-round-2-x-2-with-axle-hole/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/614301.jpg",
        "external_ids": {
          "BrickOwl": [
            "997602"
          ],
          "LDraw": [
            "3941",
            "6143"
          ],
          "LEGO": [
            "39223",
            "6116",
            "6143"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 57,
      "part": {
        "part_num": "6141",
        "name": "Plate Round 1 x 1 with Solid Stud",
        "part_cat_id": 21,
        "part_url": "https://rebrickable.com/parts/6141/plate-round-1-x-1-with-solid-stud/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/614126.jpg",
        "external_ids": {
          "BrickLink": [
            "4073"
          ],
          "BrickOwl": [
            "961948"
          ],
          "LEGO": [
            "15570",
            "30057",
            "44325",
            "51809"
          ],
          "Peeron": [
            "4073"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 5,
      "part": {
        "part_num": "4599b",
        "name": "Tap 1 x 1 without Hole in Spout",
        "part_cat_id": 27,
        "part_url": "https://rebrickable.com/parts/4599b/tap-1-x-1-without-hole-in-spout/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211503.jpg",
        "external_ids": {
          "BrickOwl": [
            "733456"
          ],
          "LEGO": [
            "4599"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 48,
      "part": {
        "part_num": "3022",
        "name": "Plate 2 x 2",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3022/plate-2-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302226.jpg",
        "external_ids": {
          "BrickOwl": [
            "566026"
          ],
          "LDraw": [
            "94148"
          ],
          "LEGO": [
            "94148"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 50,
      "part": {
        "part_num": "85984",
        "name": "Slope 30° 1 x 2 x 2/3",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/85984/slope-30-1-x-2-x-23/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4568637.jpg",
        "external_ids": {
          "BrickOwl": [
            "444606"
          ],
          "Peeron": [
            "x1972"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 15,
      "part": {
        "part_num": "63864",
        "name": "Tile 1 x 3",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/63864/tile-1-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4558169.jpg",
        "external_ids": {
          "BrickOwl": [
            "276668"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 17,
      "part": {
        "part_num": "2431",
        "name": "Tile 1 x 4 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/2431/tile-1-x-4-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/243101.jpg",
        "external_ids": {
          "BrickOwl": [
            "853045"
          ],
          "Brickset": [
            "2431",
            "35371"
          ],
          "LEGO": [
            "2431",
            "35371",
            "91143"
          ],
          "Peeron": [
            "2431b"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 69,
      "part": {
        "part_num": "6536",
        "name": "Technic Axle and Pin Connector Perpendicular",
        "part_cat_id": 12,
        "part_url": "https://rebrickable.com/parts/6536/technic-axle-and-pin-connector-perpendicular/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4173668.jpg",
        "external_ids": {
          "BrickOwl": [
            "80612"
          ],
          "LEGO": [
            "40146"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 27,
      "part": {
        "part_num": "3010",
        "name": "Brick 1 x 4",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3010/brick-1-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/301001.jpg",
        "external_ids": {
          "BrickOwl": [
            "752369"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 15,
      "part": {
        "part_num": "3665",
        "name": "Slope Inverted 45° 2 x 1",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/3665/slope-inverted-45-2-x-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/366526.jpg",
        "external_ids": {
          "BrickOwl": [
            "320373"
          ],
          "LDraw": [
            "3665a"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 13,
      "part": {
        "part_num": "4070",
        "name": "Brick Special 1 x 1 with Headlight and No Slot",
        "part_cat_id": 5,
        "part_url": "https://rebrickable.com/parts/4070/brick-special-1-x-1-with-headlight-and-no-slot/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/407026.jpg",
        "external_ids": {
          "BrickLink": [
            "4070"
          ],
          "BrickOwl": [
            "475629"
          ],
          "Brickset": [
            "35388",
            "4070"
          ],
          "LDraw": [
            "30069"
          ],
          "LEGO": [
            "30069",
            "35388",
            "4070"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 25,
      "part": {
        "part_num": "3460",
        "name": "Plate 1 x 8",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3460/plate-1-x-8/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/346026.jpg",
        "external_ids": {
          "BrickOwl": [
            "840367"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 14,
      "part": {
        "part_num": "3001",
        "name": "Brick 2 x 4",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3001/brick-2-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300121.jpg",
        "external_ids": {
          "BrickOwl": [
            "771344"
          ],
          "LEGO": [
            "15589",
            "54534",
            "72841"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 50,
      "part": {
        "part_num": "3710",
        "name": "Plate 1 x 4",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3710/plate-1-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/371026.jpg",
        "external_ids": {
          "BrickOwl": [
            "515555"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 31,
      "part": {
        "part_num": "15068",
        "name": "Slope Curved 2 x 2 x 2/3",
        "part_cat_id": 37,
        "part_url": "https://rebrickable.com/parts/15068/slope-curved-2-x-2-x-23/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6047220.jpg",
        "external_ids": {
          "BrickOwl": [
            "593875"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 19,
      "part": {
        "part_num": "3003",
        "name": "Brick 2 x 2",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3003/brick-2-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300301.jpg",
        "external_ids": {
          "BrickLink": [
            "3003"
          ],
          "BrickOwl": [
            "3003",
            "939628"
          ],
          "LDraw": [
            "3003"
          ],
          "LEGO": [
            "15591",
            "3003",
            "62404"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 13,
      "part": {
        "part_num": "32525",
        "name": "Technic Beam 1 x 11 Thick",
        "part_cat_id": 51,
        "part_url": "https://rebrickable.com/parts/32525/technic-beam-1-x-11-thick/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4156150.jpg",
        "external_ids": {
          "BrickOwl": [
            "441127"
          ],
          "LEGO": [
            "64290"
          ],
          "Peeron": [
            "x121"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "26603",
        "name": "Tile 2 x 3",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/26603/tile-2-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6156667.jpg",
        "external_ids": {
          "BrickOwl": [
            "372299"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "15458",
        "name": "Technic Panel 3 X 11 x 1",
        "part_cat_id": 40,
        "part_url": "https://rebrickable.com/parts/15458/technic-panel-3-x-11-x-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6127205.jpg",
        "external_ids": {
          "BrickOwl": [
            "806951"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 57,
      "part": {
        "part_num": "54200",
        "name": "Slope 30° 1 x 1 x 2/3 (Cheese Slope)",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/54200/slope-30-1-x-1-x-23-cheese-slope/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4504382.jpg",
        "external_ids": {
          "BrickOwl": [
            "158788"
          ],
          "LEGO": [
            "18862",
            "33847",
            "35338",
            "50746",
            "54200",
            "63290"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 29,
      "part": {
        "part_num": "60483",
        "name": "Technic Beam 1 x 2 Thick with Pin Hole and Axle Hole",
        "part_cat_id": 51,
        "part_url": "https://rebrickable.com/parts/60483/technic-beam-1-x-2-thick-with-pin-hole-and-axle-hole/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4515185.jpg",
        "external_ids": {
          "BrickOwl": [
            "251668"
          ],
          "LDraw": [
            "60483"
          ],
          "LEGO": [
            "40147",
            "74695"
          ],
          "Peeron": [
            "x1835"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 25,
      "part": {
        "part_num": "3795",
        "name": "Plate 2 x 6",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3795/plate-2-x-6/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/379526.jpg",
        "external_ids": {
          "BrickOwl": [
            "735504"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 12,
      "part": {
        "part_num": "3068b",
        "name": "Tile 2 x 2 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/3068b/tile-2-x-2-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/306801.jpg",
        "external_ids": {
          "BrickOwl": [
            "462122"
          ],
          "LEGO": [
            "3068",
            "63327"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 10,
      "part": {
        "part_num": "15207",
        "name": "Panel 1 x 4 x 1 with Rounded Corners [Thin Wall]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/15207/panel-1-x-4-x-1-with-rounded-corners-thin-wall/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6071299.jpg",
        "external_ids": {
          "BrickLink": [
            "30413"
          ],
          "BrickOwl": [
            "267165"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 11,
      "part": {
        "part_num": "32064a",
        "name": "Technic Brick 1 x 2 with Axle Hole Type 1 [+ Opening] and Bottom Pin",
        "part_cat_id": 8,
        "part_url": "https://rebrickable.com/parts/32064a/technic-brick-1-x-2-with-axle-hole-type-1-opening-and-bottom-pin/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4210935.jpg",
        "external_ids": {
          "BrickLink": [
            "32064"
          ],
          "BrickOwl": [
            "844353"
          ],
          "LEGO": [
            "31493",
            "32064"
          ],
          "Peeron": [
            "32064"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 28,
      "part": {
        "part_num": "6636",
        "name": "Tile 1 x 6 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/6636/tile-1-x-6-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211549.jpg",
        "external_ids": {
          "BrickOwl": [
            "154034"
          ],
          "LEGO": [
            "63324"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 6,
      "part": {
        "part_num": "27925",
        "name": "Tile 2 x 2 Curved, Macaroni",
        "part_cat_id": 67,
        "part_url": "https://rebrickable.com/parts/27925/tile-2-x-2-curved-macaroni/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6163990.jpg",
        "external_ids": {
          "BrickOwl": [
            "281026"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 4,
      "part": {
        "part_num": "3008",
        "name": "Brick 1 x 8",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3008/brick-1-x-8/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300801.jpg",
        "external_ids": {
          "BrickOwl": [
            "273019"
          ],
          "LDraw": [
            "3008",
            "63322"
          ],
          "LEGO": [
            "63322"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 8,
      "part": {
        "part_num": "3009",
        "name": "Brick 1 x 6",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3009/brick-1-x-6/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300901.jpg",
        "external_ids": {
          "BrickOwl": [
            "340943"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 11,
      "part": {
        "part_num": "41879a",
        "name": "Legs Short [without Hole]",
        "part_cat_id": 61,
        "part_url": "https://rebrickable.com/parts/41879a/legs-short-without-hole/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4162345.jpg",
        "external_ids": {
          "BrickLink": [
            "41879"
          ],
          "BrickOwl": [
            "203730"
          ],
          "LEGO": [
            "41879",
            "90380"
          ],
          "Peeron": [
            "41879"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "3747b",
        "name": "Slope Inverted 33° 3 x 2 [Connections between Studs]",
        "part_cat_id": 3,
        "part_url": "https://rebrickable.com/parts/3747b/slope-inverted-33-3-x-2-connections-between-studs/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211064.jpg",
        "external_ids": {
          "BrickOwl": [
            "941188"
          ],
          "LEGO": [
            "3747"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 30,
      "part": {
        "part_num": "3004",
        "name": "Brick 1 x 2",
        "part_cat_id": 11,
        "part_url": "https://rebrickable.com/parts/3004/brick-1-x-2/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/300401.jpg",
        "external_ids": {
          "BrickOwl": [
            "442413"
          ],
          "LDraw": [
            "93792"
          ],
          "LEGO": [
            "93792"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 6,
      "part": {
        "part_num": "14769",
        "name": "Tile Round 2 x 2 with Bottom Stud Holder",
        "part_cat_id": 67,
        "part_url": "https://rebrickable.com/parts/14769/tile-round-2-x-2-with-bottom-stud-holder/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6052200.jpg",
        "external_ids": {
          "BrickOwl": [
            "333997"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 49,
      "part": {
        "part_num": "3020",
        "name": "Plate 2 x 4",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3020/plate-2-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302026.jpg",
        "external_ids": {
          "BrickOwl": [
            "80025"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 11,
      "part": {
        "part_num": "4081b",
        "name": "Plate Special 1 x 1 with Clip Light [Thick Ring]",
        "part_cat_id": 9,
        "part_url": "https://rebrickable.com/parts/4081b/plate-special-1-x-1-with-clip-light-thick-ring/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/408126.jpg",
        "external_ids": {
          "BrickOwl": [
            "194287"
          ],
          "Brickset": [
            "4018",
            "41632"
          ],
          "LEGO": [
            "4081",
            "41632"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 11,
      "part": {
        "part_num": "60479",
        "name": "Plate 1 x 12",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/60479/plate-1-x-12/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4514846.jpg",
        "external_ids": {
          "BrickOwl": [
            "43273"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "4865a",
        "name": "Panel 1 x 2 x 1 [Square Corners]",
        "part_cat_id": 23,
        "part_url": "https://rebrickable.com/parts/4865a/panel-1-x-2-x-1-square-corners/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/486501.jpg",
        "external_ids": {
          "BrickLink": [
            "4865"
          ],
          "BrickOwl": [
            "746621"
          ],
          "LEGO": [
            "30010",
            "4865"
          ],
          "Peeron": [
            "4865"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 17,
      "part": {
        "part_num": "970c00",
        "name": "Legs and Hips [Complete Assembly]",
        "part_cat_id": 61,
        "part_url": "https://rebrickable.com/parts/970c00/legs-and-hips-complete-assembly/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4569093.jpg",
        "external_ids": {
          "BrickOwl": [
            "639708",
            "863328"
          ],
          "LDraw": [
            "3815c01"
          ],
          "LEGO": [
            "73200",
            "88584"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 41,
      "part": {
        "part_num": "3070b",
        "name": "Tile 1 x 1 with Groove",
        "part_cat_id": 19,
        "part_url": "https://rebrickable.com/parts/3070b/tile-1-x-1-with-groove/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211415.jpg",
        "external_ids": {
          "BrickOwl": [
            "55275"
          ],
          "Brickset": [
            "3070b",
            "35403"
          ],
          "LEGO": [
            "30039",
            "3070",
            "35403"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 14,
      "part": {
        "part_num": "4740",
        "name": "Dish 2 x 2 Inverted [Radar]",
        "part_cat_id": 21,
        "part_url": "https://rebrickable.com/parts/4740/dish-2-x-2-inverted-radar/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/474026.jpg",
        "external_ids": {
          "BrickOwl": [
            "739988"
          ],
          "Brickset": [
            "35395",
            "4740"
          ],
          "LEGO": [
            "17964",
            "30063",
            "35395",
            "71874"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 22,
      "part": {
        "part_num": "87994",
        "name": "Bar 3L",
        "part_cat_id": 32,
        "part_url": "https://rebrickable.com/parts/87994/bar-3l/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4566275.jpg",
        "external_ids": {
          "BrickOwl": [
            "359273"
          ],
          "LEGO": [
            "17715",
            "19385"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 24,
      "part": {
        "part_num": "4032a",
        "name": "Plate Round 2 x 2 with Axle Hole Type 1 (+ Opening)",
        "part_cat_id": 21,
        "part_url": "https://rebrickable.com/parts/4032a/plate-round-2-x-2-with-axle-hole-type-1-opening/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/403226.jpg",
        "external_ids": {
          "BrickLink": [
            "4032"
          ],
          "BrickOwl": [
            "680648"
          ],
          "LEGO": [
            "4032"
          ],
          "Peeron": [
            "4032"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 4,
      "part": {
        "part_num": "27263",
        "name": "Tile Special 2 x 2 Corner with Cut Corner - Facet",
        "part_cat_id": 15,
        "part_url": "https://rebrickable.com/parts/27263/tile-special-2-x-2-corner-with-cut-corner-facet/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6168612.jpg",
        "external_ids": {
          "BrickOwl": [
            "753997"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 8,
      "part": {
        "part_num": "41769",
        "name": "Wedge Plate 4 x 2 Right",
        "part_cat_id": 49,
        "part_url": "https://rebrickable.com/parts/41769/wedge-plate-4-x-2-right/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4160869.jpg",
        "external_ids": {
          "BrickOwl": [
            "886867"
          ],
          "LEGO": [
            "63330"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 19,
      "part": {
        "part_num": "60474",
        "name": "Plate Round 4 x 4 with Pin Hole",
        "part_cat_id": 21,
        "part_url": "https://rebrickable.com/parts/60474/plate-round-4-x-4-with-pin-hole/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4515351.jpg",
        "external_ids": {
          "BrickOwl": [
            "878683"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "57895",
        "name": "Glass for Window 1 x 4 x 6",
        "part_cat_id": 16,
        "part_url": "https://rebrickable.com/parts/57895/glass-for-window-1-x-4-x-6/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4500813.jpg",
        "external_ids": {
          "BrickOwl": [
            "66699"
          ],
          "Brickset": [
            "35294",
            "35295",
            "60803"
          ],
          "LDraw": [
            "57895",
            "60803"
          ],
          "LEGO": [
            "35294",
            "35295",
            "60803"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 2,
      "part": {
        "part_num": "28326",
        "name": "Mudguard 3X4, W/ Plate, No. 1",
        "part_cat_id": 36,
        "part_url": "https://rebrickable.com/parts/28326/mudguard-3x4-w-plate-no-1/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6178912.jpg",
        "external_ids": {
          "BrickOwl": [
            "220470"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 5,
      "part": {
        "part_num": "43719",
        "name": "Wedge Plate 4 x 4 with 2 x 2 Cutout",
        "part_cat_id": 49,
        "part_url": "https://rebrickable.com/parts/43719/wedge-plate-4-x-4-with-2-x-2-cutout/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4234932.jpg",
        "external_ids": {
          "BrickOwl": [
            "239356"
          ],
          "Brickset": [
            "41822",
            "43719"
          ],
          "LEGO": [
            "41822",
            "43719"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 36,
      "part": {
        "part_num": "3021",
        "name": "Plate 2 x 3",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3021/plate-2-x-3/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/302126.jpg",
        "external_ids": {
          "BrickOwl": [
            "960521"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 1,
      "part": {
        "part_num": "28324",
        "name": "Vehicle Base 6 x 12 x 3/4 with 4 x 2 Recessed Center with Smooth Underside",
        "part_cat_id": 36,
        "part_url": "https://rebrickable.com/parts/28324/vehicle-base-6-x-12-x-34-with-4-x-2-recessed-center-with-smooth-underside/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/6170384.jpg",
        "external_ids": {
          "BrickOwl": [
            "12480"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 32,
      "part": {
        "part_num": "3666",
        "name": "Plate 1 x 6",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3666/plate-1-x-6/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/366626.jpg",
        "external_ids": {
          "BrickOwl": [
            "804561"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 10,
      "part": {
        "part_num": "3031",
        "name": "Plate 4 x 4",
        "part_cat_id": 14,
        "part_url": "https://rebrickable.com/parts/3031/plate-4-x-4/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/303126.jpg",
        "external_ids": {
          "BrickOwl": [
            "163746"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    },
    {
      "quantity": 3,
      "part": {
        "part_num": "43723",
        "name": "Wedge Plate 3 x 2 Left",
        "part_cat_id": 49,
        "part_url": "https://rebrickable.com/parts/43723/wedge-plate-3-x-2-left/",
        "part_img_url": "https://cdn.rebrickable.com/media/parts/elements/4211794.jpg",
        "external_ids": {
          "BrickOwl": [
            "724978"
          ]
        },
        "print_of": null
      },
      "color": {
        "id": 0,
        "name": "Black",
        "rgb": "05131D",
        "is_trans": null,
        "external_ids": {
          "BrickLink": {
            "ext_ids": [
              11
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "BrickOwl": {
            "ext_ids": [
              38
            ],
            "ext_descrs": [
              [
                "Black"
              ]
            ]
          },
          "LEGO": {
            "ext_ids": [
              26,
              149,
              1012
            ],
            "ext_descrs": [
              [
                "Black",
                "BLACK"
              ],
              [
                "Metallic Black",
                "MET.BLACK"
              ],
              [
                "CONDUCT. BLACK"
              ]
            ]
          },
          "Peeron": {
            "ext_ids": [
              null
            ],
            "ext_descrs": [
              [
                "black"
              ]
            ]
          },
          "LDraw": {
            "ext_ids": [
              0,
              256
            ],
            "ext_descrs": [
              [
                "Black"
              ],
              [
                "Rubber_Black"
              ]
            ]
          }
        }
      }
    }
  ]
}"
# Out:
#   File "<ipython-input-31-7118b1f40d76>", line 1
#     jsonstring = "{
#                    ^
# SyntaxError: EOL while scanning string literal
